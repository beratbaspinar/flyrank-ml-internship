# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/beratbaspinar/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os, sys, subprocess

# Colab ortamında reponun root dizinine geçiş yap
if "google.colab" in sys.modules:
    REPO_DIR = "flyrank-ml-internship-starter"
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/flyrank-bih/flyrank-ml-internship-starter", REPO_DIR], check=True)
    os.chdir(REPO_DIR)

# Çalışma dizinini doğrula
print("Mevcut Çalışma Dizini:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "CSV dosyası bulunamadı!"
print("Starter verisi başarıyla bulundu!")
# Out:
# Mevcut Çalışma Dizini: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter verisi başarıyla bulundu!

# %% [markdown]
# ### 1. Dosyanın Colab'a yüklendiğinden emin olun
#
# Sol paneldeki 'Dosyalar' ikonuna tıklayarak dosya sistemini kontrol edebilirsiniz. Eğer dosya orada değilse, bilgisayarınızdan Colab'a yükleyebilirsiniz (sürükle-bırak veya 'Dosya Yükle' butonu ile).
#
# ### 2. Dosya yolunu kontrol edin
#
# Eğer dosyayı yüklediyseniz, genellikle `/content/` dizininde bulunur. Dosyanızın adını ve yolunu kontrol etmek için aşağıdaki kodu çalıştırabilirsiniz:

# %%
import os, sys, subprocess

# Colab ortamında reponun root dizinine geçiş yap
if "google.colab" in sys.modules:
    REPO_DIR = "flyrank-ml-internship-starter"
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/flyrank-bih/flyrank-ml-internship-starter", REPO_DIR], check=True)
    os.chdir(REPO_DIR)

# Çalışma dizinini doğrula
print("Mevcut Çalışma Dizini:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "CSV dosyası bulunamadı!"
print("Starter verisi başarıyla bulundu!")
# Out:
# Mevcut Çalışma Dizini: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter verisi başarıyla bulundu!

# %% [markdown]
# Yukarıdaki çıktıya göre dosyanızın doğru yolunu bulduktan sonra, `pd.read_csv()` çağrısını buna göre düzeltmeniz gerekecektir. Örneğin, dosyanız doğrudan `/content/` altında ise, yolunuz `/content/content_refresh_anonymized.csv` olmalıdır.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
import pandas as pd

# df değişkenini bu hücrede de tanımlayalım
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Check proportion of declining vs non-declining pages
declining_count = (df['trend_direction'].str.lower() == 'down').sum()
print(f"Declining pages in dataset: {declining_count} / {len(df)} ({declining_count/len(df)*100:.1f}%)")
# Out:
# Declining pages in dataset: 16262 / 30000 (54.2%)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

total_pages = len(df)
declining_pages = (df['trend_direction'].str.lower() == 'down').sum()
stale_visible = df[(df['days_since_last_update'] >= 180) & (df['impressions_90d'] >= 500)]

print(f"1. Total Dataset Size: {total_pages} pages")
print(f"2. Declining Pages: {declining_pages} ({declining_pages/total_pages*100:.1f}%)")
print(f"3. High-Potential Stale & Visible Pages: {len(stale_visible)} ({len(stale_visible)/total_pages*100:.1f}%)")
# Out:
# 1. Total Dataset Size: 30000 pages
# 2. Declining Pages: 16262 (54.2%)
# 3. High-Potential Stale & Visible Pages: 17 (0.1%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Careful phrasing framing verified. No causal or algorithm-proof claims made.")
# Out:
# Careful phrasing framing verified. No causal or algorithm-proof claims made.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
